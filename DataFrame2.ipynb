# %%
import pandas as pd
sd=pd.read_csv("people.csv")
sd
# Out:
#    id forenames surname title        address1         address2       town  \
# 0   1     Polly  Parrot  Miss     42 The Lane              NaN  Some Town
# 1   2     Mabel  Canary   Mrs   24 The Street     Some Village  Some Town
# 2   3       Zöe   Zebra    Ms  856 The Avenue              NaN  Some City
# 3   4      José   Arara   NaN     Nenhuma Rua              NaN  São Paulo
# 4   5    Dickie    Duck    Mr    1 The Street  Another Village  Some City
# 5   6      Fred  Canary    Mr   24 The Street     Some Village  Some Town
#
#          county country postcode  subscribed gender         dob
# 0       Noshire      gb  AB1 2XY           1      f  1970-12-31
# 1       Noshire      gb  AB1 2YZ           0      f  1968-01-23
# 2            CA      us   123456           1      f  1989-07-16
# 3           NaN      br   123457           1      m  1991-05-30
# 4  Imagineshire      gb  YZ1 2AB           0      m  1952-11-25
# 5       Noshire      gb  AB1 2YZ           1      m  1967-08-04

# %%
sd["phone"]="7248367610"
sd
# Out:
#    id forenames surname title        address1         address2       town  \
# 0   1     Polly  Parrot  Miss     42 The Lane              NaN  Some Town
# 1   2     Mabel  Canary   Mrs   24 The Street     Some Village  Some Town
# 2   3       Zöe   Zebra    Ms  856 The Avenue              NaN  Some City
# 3   4      José   Arara   NaN     Nenhuma Rua              NaN  São Paulo
# 4   5    Dickie    Duck    Mr    1 The Street  Another Village  Some City
# 5   6      Fred  Canary    Mr   24 The Street     Some Village  Some Town
#
#          county country postcode  subscribed gender         dob       phone
# 0       Noshire      gb  AB1 2XY           1      f  1970-12-31  7248367610
# 1       Noshire      gb  AB1 2YZ           0      f  1968-01-23  7248367610
# 2            CA      us   123456           1      f  1989-07-16  7248367610
# 3           NaN      br   123457           1      m  1991-05-30  7248367610
# ...

# %%
sd["Sports"]="Cricket"
sd
# Out:
#    id forenames surname title        address1         address2       town  \
# 0   1     Polly  Parrot  Miss     42 The Lane              NaN  Some Town
# 1   2     Mabel  Canary   Mrs   24 The Street     Some Village  Some Town
# 2   3       Zöe   Zebra    Ms  856 The Avenue              NaN  Some City
# 3   4      José   Arara   NaN     Nenhuma Rua              NaN  São Paulo
# 4   5    Dickie    Duck    Mr    1 The Street  Another Village  Some City
# 5   6      Fred  Canary    Mr   24 The Street     Some Village  Some Town
#
#          county country postcode  subscribed gender         dob       phone  \
# 0       Noshire      gb  AB1 2XY           1      f  1970-12-31  7248367610
# 1       Noshire      gb  AB1 2YZ           0      f  1968-01-23  7248367610
# 2            CA      us   123456           1      f  1989-07-16  7248367610
# 3           NaN      br   123457           1      m  1991-05-30  7248367610
# ...

# %%
import pandas as pd
sd=pd.read_csv("people.csv")
sd
# Out:
#    id forenames surname title        address1         address2       town  \
# 0   1     Polly  Parrot  Miss     42 The Lane              NaN  Some Town
# 1   2     Mabel  Canary   Mrs   24 The Street     Some Village  Some Town
# 2   3       Zöe   Zebra    Ms  856 The Avenue              NaN  Some City
# 3   4      José   Arara   NaN     Nenhuma Rua              NaN  São Paulo
# 4   5    Dickie    Duck    Mr    1 The Street  Another Village  Some City
# 5   6      Fred  Canary    Mr   24 The Street     Some Village  Some Town
#
#          county country postcode  subscribed gender         dob
# 0       Noshire      gb  AB1 2XY           1      f  1970-12-31
# 1       Noshire      gb  AB1 2YZ           0      f  1968-01-23
# 2            CA      us   123456           1      f  1989-07-16
# 3           NaN      br   123457           1      m  1991-05-30
# 4  Imagineshire      gb  YZ1 2AB           0      m  1952-11-25
# 5       Noshire      gb  AB1 2YZ           1      m  1967-08-04

# %%
sd.insert(3,column="Sports",value="Cricket")
sd
# Out:
#    id forenames surname   Sports title        address1         address2  \
# 0   1     Polly  Parrot  Cricket  Miss     42 The Lane              NaN
# 1   2     Mabel  Canary  Cricket   Mrs   24 The Street     Some Village
# 2   3       Zöe   Zebra  Cricket    Ms  856 The Avenue              NaN
# 3   4      José   Arara  Cricket   NaN     Nenhuma Rua              NaN
# 4   5    Dickie    Duck  Cricket    Mr    1 The Street  Another Village
# 5   6      Fred  Canary  Cricket    Mr   24 The Street     Some Village
#
#         town        county country postcode  subscribed gender         dob
# 0  Some Town       Noshire      gb  AB1 2XY           1      f  1970-12-31
# 1  Some Town       Noshire      gb  AB1 2YZ           0      f  1968-01-23
# 2  Some City            CA      us   123456           1      f  1989-07-16
# 3  São Paulo           NaN      br   123457           1      m  1991-05-30
# 4  Some City  Imagineshire      gb  YZ1 2AB           0      m  1952-11-25
# ...
